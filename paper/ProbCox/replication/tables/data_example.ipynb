# %% [markdown]
# # Replication - Example data - Table
#
# Here we provide a notebook to replicate the simulation results for the small data example table in the main paper.
#
# The notebook replicates the results in:
# - /out/simulation/tables/example.csv
#
# The main script can be found at:
# - /scripts/simulation/tables/data_example.py

# %%
# google colab specific - installing probcox
# !pip3 install probcox
# Out:
# Requirement already satisfied: probcox in /usr/local/lib/python3.7/dist-packages (0.0.5)
# Requirement already satisfied: pyro-ppl<1.6 in /usr/local/lib/python3.7/dist-packages (from probcox) (1.5.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from probcox) (1.19.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from probcox) (1.8.1+cu101)
# Requirement already satisfied: tqdm>=4.36 in /usr/local/lib/python3.7/dist-packages (from pyro-ppl<1.6->probcox) (4.41.1)
# Requirement already satisfied: pyro-api>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from pyro-ppl<1.6->probcox) (0.1.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from pyro-ppl<1.6->probcox) (3.3.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->probcox) (3.7.4.3)

# %%
# Modules
# =======================================================================================================================

import os
import sys
import shutil
import subprocess
import tqdm

import numpy as np
import pandas as pd

import torch
from torch.distributions import constraints

import pyro
import pyro.distributions as dist

from pyro.infer import SVI, Trace_ELBO

import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

import probcox as pcox

dtype = torch.FloatTensor

np.random.seed(909)
torch.manual_seed(9034)

# %%
# Simulation Settings
# =======================================================================================================================

I = 1000 # Number of Individuals
P_binary = 3
P_continuous = 3
P = P_binary + P_continuous
theta = np.asarray([-0.1, 0.8, 0, 0.8, 1.5, 0])[:, None]
scale = 0.5  # Scaling factor for Baseline Hazard

# %%
# Simulation
# =======================================================================================================================

TVC = pcox.TVC(theta=theta, P_binary=P_binary, P_continuous=P_continuous, dtype=dtype)
TVC.make_lambda0(scale=scale)

surv = torch.zeros((0, 3))
X = torch.zeros((0, 6))
for __ in (range(3)):
    a, b = TVC.sample()
    surv = torch.cat((surv, a))
    X = torch.cat((X, b))

# %%
# Table
# =======================================================================================================================
dd = pd.DataFrame(np.round(surv.numpy().astype(int), 2))
X = pd.DataFrame(np.round(X.numpy(), 2))

dd = pd.concat([dd, X], axis=1)
dd.columns = ['start', 'stop', 'event' ,'X1' ,'X2' ,'X3' ,'X4' ,'X5' ,'X6']

# %%
dd # for the paper we removed the second individuals to save space.
# Out:
#     start   stop  event   X1   X2   X3    X4    X5    X6
# 0       0   1000      0  0.0  0.0  0.0  0.00  0.00  0.00
# 1    1000   3235      0  1.0  0.0  0.0 -1.22 -0.30  0.61
# 2    3235   6671      0  0.0  0.0  1.0  0.14  0.32  0.61
# 3    6671   8551      0  0.0  0.0  0.0 -0.76 -0.20  0.65
# 4    8551  10146      0  0.0  1.0  1.0 -0.19 -0.52  0.13
# 5   10146  11107      1  0.0  1.0  0.0  1.55  0.85  1.84
# 6       0   2322      0  0.0  0.0  0.0  0.00  0.00  0.00
# 7    2322   3193      0  0.0  0.0  0.0 -0.18  0.93 -0.17
# 8    3193   6091      0  0.0  0.0  0.0  0.35  0.93 -1.26
# 9    6091   8118      0  1.0  0.0  1.0  0.51  2.43  0.26
# 10   8118   8169      1  0.0  0.0  0.0  1.18  0.86  0.54
# 11      0   3693      0  0.0  0.0  0.0  0.00  0.00  0.00
# 12   3693   5421      0  0.0  0.0  0.0 -0.42 -1.87  0.34
# 13   5421   7291      0  0.0  0.0  0.0  0.64 -2.43  0.51
# 14   7291   9852      0  0.0  0.0  0.0  0.09  0.03  0.71
# 15   9852  10004      0  0.0  0.0  0.0 -1.23  0.76 -0.03
